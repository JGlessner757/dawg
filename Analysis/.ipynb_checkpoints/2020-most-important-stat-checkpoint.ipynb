# %% [markdown]
# # The Most Important Stat in College Football
# ## 2020 Edition
#
# Welcome back college football nuts, former players, coaches and broadcasters to this years data driven dive into the world of NCAA football.
#
# This year was an odd season, with the pandemic playing a major factor in just about every aspect of the sport.  But since __[last years](https://topdawganalytics.com/blog/most-important-stat-in-college-football-2019/)__ study was so suprisingly convincing in its conclusion, we decided to revisit our findings for the 2020 season.  Did our analysis from last season hold up?
#
# ## Conclusions from 2019

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load in 

import numpy as np # linear algebra - is for nerds.
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
from pandas import DataFrame, Series

# These are the plotting modules adn libraries we'll use:
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as stats

# Command so that plots appear in the iPython Notebook
# %matplotlib inline

# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# Any results you write to the current directory are saved as output.

# %% [markdown]
# ## Does Defense Win Championships?
# Perhaps, but in order to win a championship, you have to win games first.  Here, we will make a statistical study utilizing Pandas, Python, Tableau and sci-kit.learn to analyze the 2019 data and see what the highest correlating factor to winning percentage is.****

# %%
#read in dataset
df = pd.read_csv('C:/Users/jgles/dawg/Analysis/cfb20.csv',sep=',')
df.head()
# Out:
#                         Team  Games  Win  Loss  Off.Rank  Off.Plays  \
# 0  Air Force (Mountain West)      6    3     3        73        373
# 1                Akron (MAC)      6    1     5       121        360
# 2              Alabama (SEC)     11   11     0         5        764
# 3       App State (Sun Belt)     12    9     3        26        845
# 4           Arizona (Pac-12)      5    0     5        86        373
#
#    Off.Yards  Off.Yards.Play  Off.TDs  Off.Yards.per.Game  ...  \
# 0       2336            6.26       19               389.3  ...
# 1       1687            4.69       12               281.2  ...
# 2       5983            7.83       68               543.9  ...
# 3       5424            6.42       49               452.0  ...
# 4       1847            4.95       10               369.4  ...
#
#    Average.Time.of.Possession.per.Game  Turnover.Rank  Fumbles.Recovered  \
# 0                                32:30             58                  3
# 1                                30:35             98                  4
# 2                                30:45             12                 10
# 3                                32:18             57                  3
# 4                                28:01            126                  1
#
#    Opponents.Intercepted  Turnovers.Gain  Fumbles.Lost  \
# 0                      5               8             5
# 1                      2               6             3
# 2                     11              21             7
# 3                     15              18             6
# 4                      2               3             5
#
#    Interceptions.Thrown.y  Turnovers.Lost  Turnover.Margin  \
# 0                       3               8                0
# 1                       6               9               -3
# 2                       4              11               10
# 3                      11              17                1
# 4                       7              12               -9
#
#    Avg.Turnover.Margin.per.Game
# 0                          0.00
# 1                         -0.50
# 2                          0.91
# 3                          0.08
# 4                         -1.80
#
# [5 rows x 152 columns]

# %%
columns = list(df)
columns
# Out:
# ['Team',
#  'Games',
#  'Win',
#  'Loss',
#  'Off.Rank',
#  'Off.Plays',
#  'Off.Yards',
#  'Off.Yards.Play',
#  'Off.TDs',
#  'Off.Yards.per.Game',
#  'Def.Rank',
#  'Def.Plays',
#  'Yards.Allowed',
#  'Yards.Play.Allowed',
#  'Off.TDs.Allowed',
#  'Total.TDs.Allowed',
#  'Yards.Per.Game.Allowed',
#  'First.Down.Rank',
#  'First.Down.Runs',
#  'First.Down.Passes',
#  'First.Down.Penalties',
#  'First.Downs',
#  'First.Down.Def.Rank',
#  'Opp.First.Down.Runs',
#  'Opp.First.Down.Passes',
#  'Opp.First.Down.Penalties',
#  'Opp.First.Downs',
#  'X4th.Down.Rank',
#  'X4th.Attempts',
#  'X4th.Conversions',
#  'X4th.Percent',
#  'X4rd.Down.Def.Rank',
#  'Opp.4th.Conversion',
#  'Opp.4th.Attempt',
#  'Opponent.4th.Percent',
#  'Kickoff.Return.Rank',
#  'Kickoffs.Returned',
#  'Kickoff.Return.Yards',
#  'Kickoff.Return.Touchdowns',
#  'Avg.Yard.per.Kickoff.Return',
#  '...40',
#  'Kickoff.Return.Def.Rank',
#  'Opp.Kickoff.Returns',
#  'Kickoff.Touchbacks',
#  'Opponent.Kickoff.Return.Yards',
#  'Opp.Kickoff.Return.Touchdowns.Allowed',
#  'Avg.Yards.per.Kickoff.Return.Allowed',
#  'Passing.Off.Rank',
#  'Pass.Attempts',
#  'Pass.Completions',
#  'Interceptions.Thrown.x',
#  'Pass.Yards',
#  'Pass.Yards.Attempt',
#  'Yards.Completion',
#  'Pass.Touchdowns',
#  'Pass.Yards.Per.Game',
#  'Pass.Def.Rank',
#  'Opp.Completions.Allowed',
#  'Opp.Pass.Attempts',
#  'Opp.Pass.Yds.Allowed',
#  'Opp.Pass.TDs.Allowed',
#  'Yards.Attempt.Allowed',
#  'Yards.Completion.Allowed',
#  'Pass.Yards.Per.Game.Allowed',
#  'Penalty.Rank',
#  'Penalties',
#  'Penalty.Yards',
#  'Penalty.Yards.Per.Game',
#  'Punt.Return.Rank',
#  'Punt.Returns',
#  'Net.Punt.Return.Yards',
#  'Punt.Return.Touchdowns',
#  'Avg.Yards.Per.Punt.Return',
#  'Punt.Return.Def.Rank',
#  'Opp.Punt.Returns',
#  'Opp.Net.Punt.Return.Yards',
#  'Opp.Punt.Return.Touchdowns.Allowed',
#  'Avg.Yards.Allowed.per.Punt.Return',
#  'Redzone.Off.Rank',
#  'Redzone.Attempts',
#  'Redzone.Rush.TD',
#  'Redzone.Pass.TD',
#  'Redzone.Field.Goals.Made',
#  'Redzone.Scores',
#  'Redzone.Points',
#  'Redzone.Def.Rank',
#  'Opp.Redzone.Attempts',
#  'Opp.Redzone.Rush.TD.Allowed',
#  'Opp.Redzone.Pass.Touchdowns.Allowed',
#  'Opp.Redzone.Field.Goals.Made',
#  'Opp.Redzone.Scores',
#  'Redzone.Points.Allowed',
#  'Rushing.Off.Rank',
#  'Rush.Attempts',
#  'Rush.Yds',
#  'Yards.Rush',
#  'Rushing.TD',
#  'Rushing.Yards.per.Game',
#  'Rushing.Def.Rank',
#  'Opp.Rush.Attempts',
#  'Opp.Rush.Yards.Alloweed',
#  'Yds.Rush.Allowed',
#  'Opp.Rush.Touchdowns.Allowed',
#  'Rush.Yards.Per.Game.Allowed',
#  'Sack.Rank',
#  'Sacks',
#  'Sack.Yards',
#  'Average.Sacks.per.Game',
#  'Scoring.Def.Rank',
#  'Touchdowns.Allowed',
#  'Opponent.Extra.Points',
#  'X2.Point.Conversions.Allowed',
#  'Opp.Deflected.Extra.Points',
#  'Opp.Feild.Goals.Made',
#  'Opp.Safety',
#  'Points.Allowed',
#  'Avg.Points.per.Game.Allowed',
#  'Scoring.Off.Rank',
#  'Touchdowns',
#  'PAT',
#  'X2.Point.Conversions',
#  'Defensive.Points',
#  'Feild.Goals',
#  'Safety',
#  'Total.Points',
#  'Points.Per.Game',
#  'Tackle.for.Loss.Rank',
#  'Solo.Tackle.For.Loss',
#  'Assist.Tackle.For.Loss',
#  'Tackle.for.Loss.Yards',
#  'Total.Tackle.For.Loss',
#  'Tackle.For.Loss.Per.Game',
#  'X3rd.Down.Rank',
#  'X3rd.Attempts',
#  'X3rd.Conversions',
#  'X3rd.Percent',
#  'X3rd.Down.Def.Rank',
#  'Opp.3rd.Conversion',
#  'Opp.3rd.Attempt',
#  'Opponent.3rd.Percent',
#  'Time.of.Possession.Rank',
#  'Time.of.Possession',
#  'Average.Time.of.Possession.per.Game',
#  'Turnover.Rank',
#  'Fumbles.Recovered',
#  'Opponents.Intercepted',
#  'Turnovers.Gain',
#  'Fumbles.Lost',
#  'Interceptions.Thrown.y',
#  'Turnovers.Lost',
#  'Turnover.Margin',
#  'Avg.Turnover.Margin.per.Game']

# %%
df.head()
# Out:
#                         Team          Tm     Conference  Games  Win  Loss  \
# 0  Air Force (Mountain West)  Air Force   Mountain West      6    3     3
# 1                Akron (MAC)      Akron             MAC      6    1     5
# 2              Alabama (SEC)    Alabama             SEC     11   11     0
# 3       App State (Sun Belt)  App State        Sun Belt     12    9     3
# 4           Arizona (Pac-12)    Arizona          Pac-12      5    0     5
#
#    Off.Rank  Off.Plays  Off.Yards  Off.Yards.Play  ...  \
# 0        73        373       2336            6.26  ...
# 1       121        360       1687            4.69  ...
# 2         5        764       5983            7.83  ...
# 3        26        845       5424            6.42  ...
# 4        86        373       1847            4.95  ...
#
#    Average.Time.of.Possession.per.Game  Turnover.Rank  Fumbles.Recovered  \
# 0                                32:30             58                  3
# 1                                30:35             98                  4
# 2                                30:45             12                 10
# 3                                32:18             57                  3
# 4                                28:01            126                  1
#
#    Opponents.Intercepted  Turnovers.Gain  Fumbles.Lost  \
# 0                      5               8             5
# 1                      2               6             3
# 2                     11              21             7
# 3                     15              18             6
# 4                      2               3             5
#
#    Interceptions.Thrown.y  Turnovers.Lost  Turnover.Margin  \
# 0                       3               8                0
# 1                       6               9               -3
# 2                       4              11               10
# 3                      11              17                1
# 4                       7              12               -9
#
#    Avg.Turnover.Margin.per.Game
# 0                          0.00
# 1                         -0.50
# 2                          0.91
# 3                          0.08
# 4                         -1.80
#
# [5 rows x 154 columns]

# %%
#separate Team, Conference, Wins, Losses and calculate Win Percentage, Average Rank(Off Rank & Def Rank), and yard diff per play

df['Win']=pd.to_numeric(df['Win'])
df1=pd.DataFrame(df.Team.str.split("(",1).tolist(), columns = ['Tm','Conf'])
#df.insert(1,'Tm',df1['Tm'])
df2=pd.DataFrame(df1.Conf.str.split(")",1).tolist(), columns = ['Conference','x'])
#df.insert(2,'Conference',df2['Conference'])
#df.drop('Team',axis=1,inplace=True)
df['winpct']=df['Win'] / df['Games']
df['Conference1']=df["Conference"].replace({"FL":"ACC","OH":"MAC"})
df.drop('Conference',axis=1,inplace=True)
df.insert(2,'Conference',df['Conference1'])
df['Avg Rank']=(df['Off.Rank']+df['Def.Rank'])/2
df['Yard Diff Per Play']=df['Off.Yards.Play'] - df['Yards.Play.Allowed']
df.head()
# Out:
#                         Team          Tm     Conference  Games  Win  Loss  \
# 0  Air Force (Mountain West)  Air Force   Mountain West      6    3     3
# 1                Akron (MAC)      Akron             MAC      6    1     5
# 2              Alabama (SEC)    Alabama             SEC     11   11     0
# 3       App State (Sun Belt)  App State        Sun Belt     12    9     3
# 4           Arizona (Pac-12)    Arizona          Pac-12      5    0     5
#
#    Off.Rank  Off.Plays  Off.Yards  Off.Yards.Play  ...  Turnovers.Gain  \
# 0        73        373       2336            6.26  ...               8
# 1       121        360       1687            4.69  ...               6
# 2         5        764       5983            7.83  ...              21
# 3        26        845       5424            6.42  ...              18
# 4        86        373       1847            4.95  ...               3
#
#    Fumbles.Lost  Interceptions.Thrown.y  Turnovers.Lost  Turnover.Margin  \
# 0             5                       3               8                0
# 1             3                       6               9               -3
# 2             7                       4              11               10
# 3             6                      11              17                1
# 4             5                       7              12               -9
#
#    Avg.Turnover.Margin.per.Game    winpct    Conference1  Avg Rank  \
# 0                          0.00  0.500000  Mountain West      40.5
# 1                         -0.50  0.166667            MAC     115.5
# 2                          0.91  1.000000            SEC      19.0
# 3                          0.08  0.750000       Sun Belt      22.0
# 4                         -1.80  0.000000         Pac-12     101.0
#
#    Yard Diff Per Play
# 0                1.20
# 1               -2.87
# 2                2.79
# 3                1.48
# 4               -1.79
#
# [5 rows x 158 columns]

# %%
list(df)
# Out:
# ['Team',
#  'Tm',
#  'Conference',
#  'Games',
#  'Win',
#  'Loss',
#  'Off.Rank',
#  'Off.Plays',
#  'Off.Yards',
#  'Off.Yards.Play',
#  'Off.TDs',
#  'Off.Yards.per.Game',
#  'Def.Rank',
#  'Def.Plays',
#  'Yards.Allowed',
#  'Yards.Play.Allowed',
#  'Off.TDs.Allowed',
#  'Total.TDs.Allowed',
#  'Yards.Per.Game.Allowed',
#  'First.Down.Rank',
#  'First.Down.Runs',
#  'First.Down.Passes',
#  'First.Down.Penalties',
#  'First.Downs',
#  'First.Down.Def.Rank',
#  'Opp.First.Down.Runs',
#  'Opp.First.Down.Passes',
#  'Opp.First.Down.Penalties',
#  'Opp.First.Downs',
#  'X4th.Down.Rank',
#  'X4th.Attempts',
#  'X4th.Conversions',
#  'X4th.Percent',
#  'X4rd.Down.Def.Rank',
#  'Opp.4th.Conversion',
#  'Opp.4th.Attempt',
#  'Opponent.4th.Percent',
#  'Kickoff.Return.Rank',
#  'Kickoffs.Returned',
#  'Kickoff.Return.Yards',
#  'Kickoff.Return.Touchdowns',
#  'Avg.Yard.per.Kickoff.Return',
#  '...40',
#  'Kickoff.Return.Def.Rank',
#  'Opp.Kickoff.Returns',
#  'Kickoff.Touchbacks',
#  'Opponent.Kickoff.Return.Yards',
#  'Opp.Kickoff.Return.Touchdowns.Allowed',
#  'Avg.Yards.per.Kickoff.Return.Allowed',
#  'Passing.Off.Rank',
#  'Pass.Attempts',
#  'Pass.Completions',
#  'Interceptions.Thrown.x',
#  'Pass.Yards',
#  'Pass.Yards.Attempt',
#  'Yards.Completion',
#  'Pass.Touchdowns',
#  'Pass.Yards.Per.Game',
#  'Pass.Def.Rank',
#  'Opp.Completions.Allowed',
#  'Opp.Pass.Attempts',
#  'Opp.Pass.Yds.Allowed',
#  'Opp.Pass.TDs.Allowed',
#  'Yards.Attempt.Allowed',
#  'Yards.Completion.Allowed',
#  'Pass.Yards.Per.Game.Allowed',
#  'Penalty.Rank',
#  'Penalties',
#  'Penalty.Yards',
#  'Penalty.Yards.Per.Game',
#  'Punt.Return.Rank',
#  'Punt.Returns',
#  'Net.Punt.Return.Yards',
#  'Punt.Return.Touchdowns',
#  'Avg.Yards.Per.Punt.Return',
#  'Punt.Return.Def.Rank',
#  'Opp.Punt.Returns',
#  'Opp.Net.Punt.Return.Yards',
#  'Opp.Punt.Return.Touchdowns.Allowed',
#  'Avg.Yards.Allowed.per.Punt.Return',
#  'Redzone.Off.Rank',
#  'Redzone.Attempts',
#  'Redzone.Rush.TD',
#  'Redzone.Pass.TD',
#  'Redzone.Field.Goals.Made',
#  'Redzone.Scores',
#  'Redzone.Points',
#  'Redzone.Def.Rank',
#  'Opp.Redzone.Attempts',
#  'Opp.Redzone.Rush.TD.Allowed',
#  'Opp.Redzone.Pass.Touchdowns.Allowed',
#  'Opp.Redzone.Field.Goals.Made',
#  'Opp.Redzone.Scores',
#  'Redzone.Points.Allowed',
#  'Rushing.Off.Rank',
#  'Rush.Attempts',
#  'Rush.Yds',
#  'Yards.Rush',
#  'Rushing.TD',
#  'Rushing.Yards.per.Game',
#  'Rushing.Def.Rank',
#  'Opp.Rush.Attempts',
#  'Opp.Rush.Yards.Alloweed',
#  'Yds.Rush.Allowed',
#  'Opp.Rush.Touchdowns.Allowed',
#  'Rush.Yards.Per.Game.Allowed',
#  'Sack.Rank',
#  'Sacks',
#  'Sack.Yards',
#  'Average.Sacks.per.Game',
#  'Scoring.Def.Rank',
#  'Touchdowns.Allowed',
#  'Opponent.Extra.Points',
#  'X2.Point.Conversions.Allowed',
#  'Opp.Deflected.Extra.Points',
#  'Opp.Feild.Goals.Made',
#  'Opp.Safety',
#  'Points.Allowed',
#  'Avg.Points.per.Game.Allowed',
#  'Scoring.Off.Rank',
#  'Touchdowns',
#  'PAT',
#  'X2.Point.Conversions',
#  'Defensive.Points',
#  'Feild.Goals',
#  'Safety',
#  'Total.Points',
#  'Points.Per.Game',
#  'Tackle.for.Loss.Rank',
#  'Solo.Tackle.For.Loss',
#  'Assist.Tackle.For.Loss',
#  'Tackle.for.Loss.Yards',
#  'Total.Tackle.For.Loss',
#  'Tackle.For.Loss.Per.Game',
#  'X3rd.Down.Rank',
#  'X3rd.Attempts',
#  'X3rd.Conversions',
#  'X3rd.Percent',
#  'X3rd.Down.Def.Rank',
#  'Opp.3rd.Conversion',
#  'Opp.3rd.Attempt',
#  'Opponent.3rd.Percent',
#  'Time.of.Possession.Rank',
#  'Time.of.Possession',
#  'Average.Time.of.Possession.per.Game',
#  'Turnover.Rank',
#  'Fumbles.Recovered',
#  'Opponents.Intercepted',
#  'Turnovers.Gain',
#  'Fumbles.Lost',
#  'Interceptions.Thrown.y',
#  'Turnovers.Lost',
#  'Turnover.Margin',
#  'Avg.Turnover.Margin.per.Game',
#  'winpct',
#  'Conference1',
#  'Avg Rank',
#  'Yard Diff Per Play']

# %%
data= df[['Team',
 'Tm',
 'Conference',
 'Games',
 'Win',
 'Loss',
 'Off.Rank',
 'Off.Plays',
 'Off.Yards',
 'Off.Yards.Play',
 'Off.TDs',
 'Off.Yards.per.Game',
 'Def.Rank',
 'Def.Plays',
 'Yards.Allowed',
 'Yards.Play.Allowed',
 'Off.TDs.Allowed',
 'Total.TDs.Allowed',
 'Yards.Per.Game.Allowed',
 'First.Down.Rank',
 'First.Down.Runs',
 'First.Down.Passes',
 'First.Down.Penalties',
 'First.Downs',
 'First.Down.Def.Rank',
 'Opp.First.Down.Runs',
 'Opp.First.Down.Passes',
 'Opp.First.Down.Penalties',
 'Opp.First.Downs',
 'X4th.Down.Rank',
 'X4th.Attempts',
 'X4th.Conversions',
 'X4th.Percent',
 'X4rd.Down.Def.Rank',
 'Opp.4th.Conversion',
 'Opp.4th.Attempt',
 'Opponent.4th.Percent',
 'Kickoff.Return.Rank',
 'Kickoffs.Returned',
 'Kickoff.Return.Yards',
 'Kickoff.Return.Touchdowns',
 'Avg.Yard.per.Kickoff.Return',
 '...40',
 'Kickoff.Return.Def.Rank',
 'Opp.Kickoff.Returns',
 'Kickoff.Touchbacks',
 'Opponent.Kickoff.Return.Yards',
 'Opp.Kickoff.Return.Touchdowns.Allowed',
 'Avg.Yards.per.Kickoff.Return.Allowed',
 'Passing.Off.Rank',
 'Pass.Attempts',
 'Pass.Completions',
 'Interceptions.Thrown.x',
 'Pass.Yards',
 'Pass.Yards.Attempt',
 'Yards.Completion',
 'Pass.Touchdowns',
 'Pass.Yards.Per.Game',
 'Pass.Def.Rank',
 'Opp.Completions.Allowed',
 'Opp.Pass.Attempts',
 'Opp.Pass.Yds.Allowed',
 'Opp.Pass.TDs.Allowed',
 'Yards.Attempt.Allowed',
 'Yards.Completion.Allowed',
 'Pass.Yards.Per.Game.Allowed',
 'Penalty.Rank',
 'Penalties',
 'Penalty.Yards',
 'Penalty.Yards.Per.Game',
 'Punt.Return.Rank',
 'Punt.Returns',
 'Net.Punt.Return.Yards',
 'Punt.Return.Touchdowns',
 'Avg.Yards.Per.Punt.Return',
 'Punt.Return.Def.Rank',
 'Opp.Punt.Returns',
 'Opp.Net.Punt.Return.Yards',
 'Opp.Punt.Return.Touchdowns.Allowed',
 'Avg.Yards.Allowed.per.Punt.Return',
 'Redzone.Off.Rank',
 'Redzone.Attempts',
 'Redzone.Rush.TD',
 'Redzone.Pass.TD',
 'Redzone.Field.Goals.Made',
 'Redzone.Scores',
 'Redzone.Points',
 'Redzone.Def.Rank',
 'Opp.Redzone.Attempts',
 'Opp.Redzone.Rush.TD.Allowed',
 'Opp.Redzone.Pass.Touchdowns.Allowed',
 'Opp.Redzone.Field.Goals.Made',
 'Opp.Redzone.Scores',
 'Redzone.Points.Allowed',
 'Rushing.Off.Rank',
 'Rush.Attempts',
 'Rush.Yds',
 'Yards.Rush',
 'Rushing.TD',
 'Rushing.Yards.per.Game',
 'Rushing.Def.Rank',
 'Opp.Rush.Attempts',
 'Opp.Rush.Yards.Alloweed',
 'Yds.Rush.Allowed',
 'Opp.Rush.Touchdowns.Allowed',
 'Rush.Yards.Per.Game.Allowed',
 'Sack.Rank',
 'Sacks',
 'Sack.Yards',
 'Average.Sacks.per.Game',
 'Scoring.Def.Rank',
 'Touchdowns.Allowed',
 'Opponent.Extra.Points',
 'X2.Point.Conversions.Allowed',
 'Opp.Deflected.Extra.Points',
 'Opp.Feild.Goals.Made',
 'Opp.Safety',
 'Points.Allowed',
 'Avg.Points.per.Game.Allowed',
 'Scoring.Off.Rank',
 'Touchdowns',
 'PAT',
 'X2.Point.Conversions',
 'Defensive.Points',
 'Feild.Goals',
 'Safety',
 'Total.Points',
 'Points.Per.Game',
 'Tackle.for.Loss.Rank',
 'Solo.Tackle.For.Loss',
 'Assist.Tackle.For.Loss',
 'Tackle.for.Loss.Yards',
 'Total.Tackle.For.Loss',
 'Tackle.For.Loss.Per.Game',
 'X3rd.Down.Rank',
 'X3rd.Attempts',
 'X3rd.Conversions',
 'X3rd.Percent',
 'X3rd.Down.Def.Rank',
 'Opp.3rd.Conversion',
 'Opp.3rd.Attempt',
 'Opponent.3rd.Percent',
 'Time.of.Possession.Rank',
 'Time.of.Possession',
 'Average.Time.of.Possession.per.Game',
 'Turnover.Rank',
 'Fumbles.Recovered',
 'Opponents.Intercepted',
 'Turnovers.Gain',
 'Fumbles.Lost',
 'Interceptions.Thrown.y',
 'Turnovers.Lost',
 'Turnover.Margin',
 'Avg.Turnover.Margin.per.Game',
 'winpct',
 'Conference1',
 'Avg Rank',
 'Yard Diff Per Play']]
correlation=data.corr(method='pearson')
correlation
# Out:
#                                  Games       Win      Loss  Off.Rank  \
# Games                         1.000000  0.583072  0.332018 -0.173749
# Win                           0.583072  1.000000 -0.572744 -0.592614
# Loss                          0.332018 -0.572744  1.000000  0.512750
# Off.Rank                     -0.173749 -0.592614  0.512750  1.000000
# Off.Plays                     0.969333  0.594962  0.287270 -0.292282
# ...                                ...       ...       ...       ...
# Turnover.Margin               0.098431  0.517006 -0.500960 -0.271064
# Avg.Turnover.Margin.per.Game  0.060712  0.459668 -0.472445 -0.283371
# winpct                        0.185754  0.873752 -0.827056 -0.646365
# Avg Rank                     -0.170831 -0.768077  0.719419  0.755880
# Yard Diff Per Play            0.171506  0.724756 -0.668439 -0.722846
#
#                               Off.Plays  Off.Yards  Off.Yards.Play   Off.TDs  \
# Games                          0.969333   0.868379        0.123495  0.722204
# Win                            0.594962   0.749019        0.578357  0.810433
# Loss                           0.287270   0.006537       -0.546903 -0.212260
# Off.Rank                      -0.292282  -0.605273       -0.883850 -0.699990
# Off.Plays                      1.000000   0.909024        0.159138  0.760942
# ...                                 ...        ...             ...       ...
# Turnover.Margin                0.105142   0.204479        0.278595  0.334750
# Avg.Turnover.Margin.per.Game   0.074052   0.168504        0.299625  0.301097
# winpct                         0.218185   0.441357        0.661297  0.583106
# Avg Rank                      -0.228562  -0.486495       -0.724876 -0.595607
# Yard Diff Per Play             0.180810   0.482921        0.838572  0.619466
#
#                               Off.Yards.per.Game  Def.Rank  ...  \
# Games                                   0.168452 -0.084541  ...
# Win                                     0.563358 -0.568646  ...
# Loss                                   -0.484127  0.574933  ...
# Off.Rank                               -0.959148  0.142923  ...
# Off.Plays                               0.295071 -0.053311  ...
# ...                                          ...       ...  ...
# Turnover.Margin                         0.260590 -0.294337  ...
# Avg.Turnover.Margin.per.Game            0.278637 -0.291742  ...
# winpct                                  0.625224 -0.634413  ...
# Avg Rank                               -0.723010  0.756022  ...
# Yard Diff Per Play                      0.723823 -0.634683  ...
#
#                               Opponents.Intercepted  Turnovers.Gain  \
# Games                                      0.621458        0.699673
# Win                                        0.605593        0.593862
# Loss                                      -0.076079        0.016460
# Off.Rank                                  -0.207713       -0.241295
# Off.Plays                                  0.621712        0.713864
# ...                                             ...             ...
# Turnover.Margin                            0.535833        0.548009
# Avg.Turnover.Margin.per.Game               0.502309        0.531440
# winpct                                     0.421118        0.379970
# Avg Rank                                  -0.310564       -0.262623
# Yard Diff Per Play                         0.306572        0.268735
#
#                               Fumbles.Lost  Interceptions.Thrown.y  \
# Games                             0.471978                0.525249
# Win                               0.104038               -0.008527
# Loss                              0.355433                0.539878
# Off.Rank                         -0.035041                0.094534
# Off.Plays                         0.472926                0.535207
# ...                                    ...                     ...
# Turnover.Margin                  -0.358618               -0.479797
# Avg.Turnover.Margin.per.Game     -0.322851               -0.452672
# winpct                           -0.107438               -0.234461
# Avg Rank                         -0.012525                0.207973
# Yard Diff Per Play                0.006355               -0.198372
#
#                               Turnovers.Lost  Turnover.Margin  \
# Games                               0.609401         0.098431
# Win                                 0.049826         0.517006
# Loss                                0.557035        -0.500960
# Off.Rank                            0.045529        -0.271064
# Off.Plays                           0.616676         0.105142
# ...                                      ...              ...
# Turnover.Margin                    -0.517895         1.000000
# Avg.Turnover.Margin.per.Game       -0.480333         0.949452
# winpct                             -0.216826         0.561435
# Avg Rank                            0.134683        -0.373968
# Yard Diff Per Play                 -0.131455         0.376771
#
#                               Avg.Turnover.Margin.per.Game    winpct  \
# Games                                             0.060712  0.185754
# Win                                               0.459668  0.873752
# Loss                                             -0.472445 -0.827056
# Off.Rank                                         -0.283371 -0.646365
# Off.Plays                                         0.074052  0.218185
# ...                                                    ...       ...
# Turnover.Margin                                   0.949452  0.561435
# Avg.Turnover.Margin.per.Game                      1.000000  0.565811
# winpct                                            0.565811  1.000000
# Avg Rank                                         -0.380391 -0.847129
# Yard Diff Per Play                                0.392509  0.808650
#
#                               Avg Rank  Yard Diff Per Play
# Games                        -0.170831            0.171506
# Win                          -0.768077            0.724756
# Loss                          0.719419           -0.668439
# Off.Rank                      0.755880           -0.722846
# Off.Plays                    -0.228562            0.180810
# ...                                ...                 ...
# Turnover.Margin              -0.373968            0.376771
# Avg.Turnover.Margin.per.Game -0.380391            0.392509
# winpct                       -0.847129            0.808650
# Avg Rank                      1.000000           -0.897888
# Yard Diff Per Play           -0.897888            1.000000
#
# [152 rows x 152 columns]

# %%
correlation.drop(correlation.columns.difference(['winpct']),1, inplace=True)
correlation.sort_values(by=['winpct'], ascending=False)

# %%
g=sns.jointplot('winpct','Def Rank',df,kind='reg')
g.annotate(stats.pearsonr)
g.fig.suptitle('DEF TEAM RANK vs WIN %')
plt.show()

# %% [markdown]
# > Regression graph for Offensive Rank and Defensive Rank Vs Win Pct with correlation
#
# Results show a stronger difference in Win Percentage and Defensive Rank...R^2 = .4225

# %% [markdown]
# **Win Percentage vs. Offensive Rank**

# %%
#Regression graph for Offensive Rank and Defensive Rank Vs Win Pct with correlation

#Results show a stronger correlation between Defensive Rank and Win Pct

g=sns.jointplot('winpct','Off Rank',df, kind='reg')
g.annotate(stats.pearsonr)
g.fig.suptitle('OFF TEAM RANK vs WIN %')
plt.show()

# %% [markdown]
# **Win Percentage vs Defensive Rank**

# %%
g=sns.jointplot('winpct','Def Rank',df,kind='reg')
g.annotate(stats.pearsonr)
plt.show()

# %% [markdown]
# **Box Plot Average Rank for Power 5 Conferences and Top 10**

# %%
filter=df['Conference']== 'ACC'
filter2=df['Conference']== 'SEC'
filter3=df['Conference']== 'Big 12'
filter4=df['Conference']== 'Big Ten' 
filter5=df['Conference']== 'Pac-12'
dfn=df.where(filter | filter2 | filter3 | filter4 | filter5)
sns.boxplot(dfn['Avg Rank'], dfn['Conference'], whis=np.inf)
plt.title('Avg Rank(Off & Def) for Power 5 Conferences')
plt.show()
df[['Tm','Off Rank','Def Rank','Avg Rank']].sort_values('Avg Rank')[0:10]

# %% [markdown]
# **Bottom 10 in Average Rank**

# %%
# Bottom 10 in Avg Rank
df[['Tm','Off Rank','Def Rank','Avg Rank']].sort_values('Avg Rank')[-10:]

# %% [markdown]
# **Rushing yards vs Passing yards per game**

# %%
#Rushing yards vs Passing yards per game
sns.jointplot(df['Pass Yards Per Game'],df["Rushing Yards per Game"],kind='scatter')

# %% [markdown]
# **Impact of Rushing and Passing Yards a game vs Win Percentage**

# %%
# How did Rushing and Passing yards affect Win Pct
forpair=df[['Pass Yards Per Game','Rushing Yards per Game','winpct']]
sns.pairplot(forpair)

# %% [markdown]
# **Turnover Rank and Win Percentage have a noticable correlation**

# %%
g=sns.jointplot('winpct','Turnover Rank',df,kind='reg')
g.annotate(stats.pearsonr)
plt.show()

# %% [markdown]
# **Highlighting the disparity of Clemson and Ohio State and the rest of their conferences**
#
# * Yard diff per play is the Yards gained per play minus the yards allowed per play

# %%
# Ohio State and Clemson Conference Disparity 

acc1=df['Conference']== 'ACC'
acc=df.where(acc1).dropna()

acc[['Tm','Win-Loss','Yard Diff Per Play', 'Turnover Margin','Off Rank','Def Rank', 'Avg Rank']].sort_values('Yard Diff Per Play', ascending=False)

# %%
big1=df['Conference']== 'Big Ten'
bigten=df.where(big1).dropna()

bigten[['Tm','Win-Loss','Yard Diff Per Play','Turnover Margin','Off Rank','Def Rank','Avg Rank']].sort_values('Yard Diff Per Play', ascending=False)

# %% [markdown]
# **LSU and Alabama did not have this same benefit with each other and UGA in the SEC**

# %%
sec1=df['Conference']== 'SEC'
sec=df.where(sec1).dropna()

sec[['Tm','Win-Loss','Yard Diff Per Play','Turnover Margin','Off Rank','Def Rank','Avg Rank']].sort_values('Yard Diff Per Play', ascending=False)
